# %% [markdown]
# <a href="https://colab.research.google.com/github/charly-smd/ada_portoSeguro/blob/main/EDA_Charlotte.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

import requests
import io
from zipfile import ZipFile
from pathlib import Path

import joblib

f"Pandas version: {pd.__version__}"
# Out:
# 'Pandas version: 2.2.2'

# %%
# mpl.style.available
mpl.style.use("seaborn-v0_8-colorblind")

# %% [markdown]
# # Porto Seguro´s Safe Driver Prediction
# Download URL and Informationen über Daten: www.openml.org/search?type=data&status=active&id=42742
# Informationen über den Datensatz aus einer Kaggel Competition im Jahr 2017: https://www.kaggle.com/c/porto-seguro-safe-driver-prediction

# %% [markdown]
# ## Download

# %%
# load dataset
from sklearn.datasets import fetch_openml
df, target = fetch_openml(
    "porto-seguro", version = 3, as_frame = True, return_X_y=True, parser = "auto"
)

# save dataset
joblib.dump((df, target), "porto_seguro_data.pkl")
# Out:
# ['porto_seguro_data.pkl']

# %%
# reload dataset without downlaoding it again
df, target = joblib.load("porto_seguro_data.pkl")

df = pd.concat(
    (df, target.to_frame(name="claims")),
    axis = "columns",
)

df.sample(10)
# Out:
#         ps_ind_01 ps_ind_02_cat  ps_ind_03 ps_ind_04_cat ps_ind_05_cat  \
# 154902        0.0             2        1.0             1             0
# 415797        4.0             1        2.0             0             0
# 22606         6.0             1        4.0             1             0
# 436541        6.0             1        7.0             1             0
# 171972        2.0             1       10.0             1             0
# 180149        1.0             1        1.0             0             0
# 407056        1.0             1        9.0             0             0
# 113271        0.0             1        5.0             1             0
# 200011        3.0             2        7.0             0             0
# 147008        0.0             1        3.0             1             0
#
#        ps_ind_06_bin ps_ind_07_bin ps_ind_08_bin ps_ind_09_bin ps_ind_10_bin  \
# 154902             0             1             0             0             0
# 415797             0             0             0             1             0
# 22606              0             1             0             0             0
# 436541             0             1             0             0             0
# 171972             0             0             0             1             0
# 180149             0             1             0             0             0
# 407056             0             0             0             1             0
# 113271             0             0             1             0             0
# 200011             0             0             0             1             0
# 147008             1             0             0             0             0
#
#         ... ps_calc_12 ps_calc_13 ps_calc_14  ps_calc_15_bin  ps_calc_16_bin  \
# 154902  ...        0.0        4.0        6.0               0               1
# 415797  ...        3.0        4.0        1.0               0               1
# 22606   ...        5.0        1.0        7.0               1               1
# 436541  ...        3.0        3.0        7.0               0               1
# 171972  ...        0.0        2.0        5.0               1               0
# 180149  ...        3.0        2.0        6.0               0               1
# 407056  ...        2.0        1.0        6.0               0               1
# 113271  ...        0.0        2.0        8.0               0               1
# 200011  ...        3.0        1.0        7.0               1               1
# 147008  ...        0.0        2.0        5.0               0               1
#
#        ps_calc_17_bin ps_calc_18_bin ps_calc_19_bin  ps_calc_20_bin  claims
# 154902              1              0              1               1       0
# 415797              0              0              1               0       0
# 22606               1              1              0               0       0
# 436541              1              1              0               1       0
# 171972              1              1              0               0       0
# 180149              1              0              1               1       0
# 407056              1              0              0               0       0
# 113271              1              1              1               1       0
# 200011              1              0              0               1       0
# 147008              0              0              1               1       0
#
# [10 rows x 58 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595212 entries, 0 to 595211
# Data columns (total 58 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ps_ind_01       595212 non-null  float64
#  1   ps_ind_02_cat   594996 non-null  category
#  2   ps_ind_03       595212 non-null  float64
#  3   ps_ind_04_cat   595129 non-null  category
#  4   ps_ind_05_cat   589403 non-null  category
#  5   ps_ind_06_bin   595212 non-null  category
#  6   ps_ind_07_bin   595212 non-null  category
#  7   ps_ind_08_bin   595212 non-null  category
#  8   ps_ind_09_bin   595212 non-null  category
#  9   ps_ind_10_bin   595212 non-null  category
#  10  ps_ind_11_bin   595212 non-null  category
#  11  ps_ind_12_bin   595212 non-null  category
#  12  ps_ind_13_bin   595212 non-null  category
#  13  ps_ind_14       595212 non-null  float64
#  14  ps_ind_15       595212 non-null  float64
#  15  ps_ind_16_bin   595212 non-null  category
#  16  ps_ind_17_bin   595212 non-null  category
#  17  ps_ind_18_bin   595212 non-null  category
#  18  ps_reg_01       595212 non-null  float64
#  19  ps_reg_02       595212 non-null  float64
#  20  ps_reg_03       487440 non-null  float64
#  21  ps_car_01_cat   595105 non-null  category
#  22  ps_car_02_cat   595207 non-null  category
#  23  ps_car_03_cat   183981 non-null  category
#  24  ps_car_04_cat   595212 non-null  category
#  25  ps_car_05_cat   328661 non-null  category
#  26  ps_car_06_cat   595212 non-null  category
#  27  ps_car_07_cat   583723 non-null  category
#  28  ps_car_08_cat   595212 non-null  category
#  29  ps_car_09_cat   594643 non-null  category
#  30  ps_car_10_cat   595212 non-null  category
#  31  ps_car_11_cat   595212 non-null  category
#  32  ps_car_11       595207 non-null  float64
#  33  ps_car_12       595211 non-null  float64
#  34  ps_car_13       595212 non-null  float64
#  35  ps_car_14       552592 non-null  float64
#  36  ps_car_15       595212 non-null  float64
#  37  ps_calc_01      595212 non-null  float64
#  38  ps_calc_02      595212 non-null  float64
#  39  ps_calc_03      595212 non-null  float64
#  40  ps_calc_04      595212 non-null  float64
#  41  ps_calc_05      595212 non-null  float64
#  42  ps_calc_06      595212 non-null  float64
#  43  ps_calc_07      595212 non-null  float64
#  44  ps_calc_08      595212 non-null  float64
#  45  ps_calc_09      595212 non-null  float64
#  46  ps_calc_10      595212 non-null  float64
#  47  ps_calc_11      595212 non-null  float64
#  48  ps_calc_12      595212 non-null  float64
#  49  ps_calc_13      595212 non-null  float64
#  50  ps_calc_14      595212 non-null  float64
#  51  ps_calc_15_bin  595212 non-null  category
#  52  ps_calc_16_bin  595212 non-null  category
#  53  ps_calc_17_bin  595212 non-null  category
#  54  ps_calc_18_bin  595212 non-null  category
#  55  ps_calc_19_bin  595212 non-null  category
#  56  ps_calc_20_bin  595212 non-null  category
#  57  claims          595212 non-null  category
# dtypes: category(32), float64(26)
# memory usage: 136.2 MB

# %% [markdown]
# ## Explorative Data Analysis (EDA)
# ### Task
# Predict whether a driver will initiate an auto insurance claim in the next year.

# %% [markdown]
# ### Numerical datatypes

# %%
(
    df.select_dtypes("number")
    .agg(["min","max","mean","median"])
)
# Out:
#         ps_ind_01  ps_ind_03  ps_ind_14  ps_ind_15  ps_reg_01  ps_reg_02  \
# min      0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# max      7.000000  11.000000   4.000000  13.000000   0.900000   1.800000
# mean     1.900378   4.423318   0.012451   7.299922   0.610991   0.439184
# median   1.000000   4.000000   0.000000   7.000000   0.700000   0.300000
#
#         ps_reg_03  ps_car_11  ps_car_12  ps_car_13  ...  ps_calc_05  \
# min      0.061237     0.0000   0.100000   0.250619  ...    0.000000
# max      4.037945     3.0000   1.264911   3.720626  ...    6.000000
# mean     0.894047     2.3461   0.379947   0.813265  ...    1.885886
# median   0.801561     3.0000   0.374166   0.765811  ...    2.000000
#
#         ps_calc_06  ps_calc_07  ps_calc_08  ps_calc_09  ps_calc_10  \
# min       0.000000    0.000000    2.000000    0.000000     0.00000
# max      10.000000    9.000000   12.000000    7.000000    25.00000
# mean      7.689445    3.005823    9.225904    2.339034     8.43359
# median    8.000000    3.000000    9.000000    2.000000     8.00000
#
#         ps_calc_11  ps_calc_12  ps_calc_13  ps_calc_14
# min       0.000000    0.000000    0.000000    0.000000
# max      19.000000   10.000000   13.000000   23.000000
# mean      5.441382    1.441918    2.872288    7.539026
# median    5.000000    1.000000    3.000000    7.000000
#
# [4 rows x 26 columns]

# %% [markdown]
# #### Observations
# ps_ind_14: Median is 0 and mean is almost 0 too
# ps_car_11: median equlas the maximum
# -> these variables probably show littlte information
#
# For some variables the mean and the median are very close to the maximum or minimum (for example ps_ind_01; ps_reg_03; ps_car_15; ps_calc_05)

# %%
# visualization
numeric_columns = df.select_dtypes(include="number").columns
fig, axes = plt.subplots(26, 1, figsize = (8,52))

for ax, name in zip(axes, numeric_columns):
    df[name].plot.kde(ax=ax, legend=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3967865933.py in <cell line: 0>()
#       4
#       5 for ax, name in zip(axes, numeric_columns):
# ----> 6     df[name].plot.kde(ax=ax, legend=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_core.py in kde(self, bw_method, ind, **kwargs)
#    1520             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1521         """
# -> 1522         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1523
#    1524     density = kde
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1028                     data.columns = label_name
#    1029
# -> 1030         return plot_backend.plot(data, kind=kind, **kwargs)
#    1031
#    1032     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     499         self._compute_plot_data()
#     500         fig = self.fig
# --> 501         self._make_plot(fig)
#     502         self._add_table()
#     503         self._make_legend()
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/hist.py in _make_plot(self, fig)
#     166             y = reformat_hist_y_given_by(y, self.by)
#     167
# --> 168             artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     169
#     170             # when by is applied, show title for subplots to know which group it is
#
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/hist.py in _plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     279         gkde = gaussian_kde(y, bw_method=bw_method)
#     280
# --> 281         y = gkde.evaluate(ind)
#     282         lines = MPLPlot._plot(ax, ind, y, style=style, **kwds)
#     283         return lines
#
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_kde.py in evaluate(self, points)
#     278
#     279         output_dtype, spec = _get_output_dtype(self.covariance, points)
# --> 280         result = gaussian_kernel_estimate[spec](
#     281             self.dataset.T, self.weights[:, None],
#     282             points.T, self.cho_cov, output_dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# #### observations
# ps_ind_14: all data are seem to be 0
# ps_calc_01: data are distributed evenly
# ps_calc_02: data are distributed evenly
# ps_calc_03: data are distributed evenly
# -> seem to carry no information
#
# the graphics show very good if variables are ordinal or distinct.

# %%
# interaction with target variable
fig, axes = plt.subplots(13, 2, figsize=(10, 26))

for ax, name in zip(axes.ravel(), numeric_columns):
    sns.violinplot(df, x=name, hue="claims", ax=ax)

# %% [markdown]
# #### Observations
# All variables don´t seem to differ between drivers who filed a claim and those who didn´t. Especially for the calc-variables the distributions show very little or no differences at all.

# %%
sns.heatmap(df.select_dtypes("number").corr(), cmap="viridis",)

# %% [markdown]
# #### Observations
# All variables with calc seem to have no interactions with the other numerical varaibles. This may be the reason they got excluded from the models in kaggle.

# %%
filtered_df = df.select_dtypes("number").loc[:, ~df.select_dtypes("number").columns.str.contains("calc")]
sns.heatmap(filtered_df.corr(), cmap="viridis")

# %% [markdown]
# #### observations
# some of the variables show high correlations, while most of them have little interactions.
# ps_reg_02 & ps_reg_03 and ps_car_12 & ps_car_13 seem to have the highest correlations.

# %%
# missing values
missing_counts = df.select_dtypes(include="number").isna().sum()
missing_rel = missing_counts / len(df)

missing_table = pd.DataFrame({
    "missing_count": missing_counts,
    "missing_ratio": missing_rel
})
missing_table

# %% [markdown]
# #### Observations
# Only two variables contain missing values:
# ps_reg_03: 18% of missing values
# ps_car_14: 7% of  missing values

# %% [markdown]
# ### Categorical variables

# %% [markdown]
# (
#   df.select_dtypes("object")
#   .drop(columns=["claims"])
#   .apply(lambda s: s.value_counts().shape[0])
#   .sort_values()
#   .plot.barh(xlabel = "number of categories")
# )

# %%
# number of Categories
(
  df.select_dtypes("category")
  .drop(columns=["claims"])
  .apply(lambda s: s.value_counts().shape[0])
  .sort_values()
  .plot.barh(xlabel = "number of categories")
)

# %% [markdown]
# The first 8 variables have more than two variables all the other seem to be dichotom. The variable "ps_car_11-cat" has a lot more categories than the others.

# %%
# distribution of target variable
print(df["claims"].value_counts(normalize = True))
df["claims"].value_counts().plot.pie()

# %% [markdown]
# only 3.7 % of the drivers filed a claim, that makes it very difficult to predict the probability.

# %%
# categories of the variable with many categories
df["ps_car_11_cat"].value_counts()

# %% [markdown]
# There are 104 categories for this variable but all seem to be filled with at least 1100 cases.

# %%
# Values count of all categorical variables
categorical_columns = df.select_dtypes(include="category").drop(columns=["claims"]).columns

fig, axes = plt.subplots(11, 3, figsize=(15, 22), layout="constrained")

for ax, colname in zip(axes.flat, categorical_columns):
    (
        df[colname]
        .value_counts(dropna = False)
        .plot.barh(ax=ax, title=colname)
    )

# %% [markdown]
# #### Observations
# ps_car_03_cat has a lot of missing values
# ps_car_05_cat has a lot of missing values
#
# In most of the dichotom variables one of the categories holds a large part of all the data.

# %%
# proportions for all binary variables
binary_columns = [
    col for col in df.columns
    if df[col].nunique(dropna=True) == 2
]

rel_freq_table = pd.DataFrame({
    col: df[col].value_counts(normalize=True, dropna = False)
    for col in binary_columns
}).T

rel_freq_table

# %% [markdown]
# #### observations:
# ps_ind_10_bin, ps_ind_11_bin, ps_ind_12_bin, ps_ind_13_bin have more than 99% of the cases in one category.

# %%
# interaction of binary categories with target variable
fig, axes = plt.subplots(8, 3, figsize=(15, 22), layout="constrained")

for ax, colname in zip(axes.flat, binary_columns):
    (
        pd.crosstab(
            index=df[colname],
            columns=df["claims"]
        )
        .pipe(lambda df_: df_.div(df_.sum(axis = "columns"), axis = "rows"))
        .plot.barh(stacked=True, title=colname, ax=ax)
    )

# %%
# interactions wit ordinal variables and target
ordinal_columns = ["ps_car_01_cat", "ps_car_04_cat", "ps_car_06_cat",
                             "ps_car_09_cat", "ps_car_10_cat", "ps_car_11_cat",
                             "ps_ind_05_cat", "ps_ind_02_cat"]
fig, axes = plt.subplots(4,2, figsize=(15, 22), layout="constrained")

for ax, colname in zip(axes.flat, ordinal_columns):
    (
        pd.crosstab(
            index=df[colname],
            columns=df["claims"]
        )
        .pipe(lambda df_: df_.div(df_.sum(axis = "columns"), axis = "rows"))
        .plot.barh(stacked=True, title=colname, ax=ax)
    )

# %% [markdown]
# #### observations
# no major hints can be observed from this graphs.
